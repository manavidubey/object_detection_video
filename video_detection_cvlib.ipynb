# %% [markdown]
# <a href="https://colab.research.google.com/github/manavidubey/object_detection_video/blob/main/video_detection_cvlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cvlib
# !pip install opencv-python

# %%
import cvlib as cv
from cvlib.object_detection import draw_bbox
import cv2
from google.colab.patches import cv2_imshow

# %%
cap = cv2.VideoCapture('vid_obj.mp4')

if not cap.isOpened():
    print("[ERROR] Could not open video file")

# %%
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# %%
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
writer = cv2.VideoWriter("object_detection_cvlib.mp4", fourcc, fps,
                         (width,height))

# %%
frame_count = 0

while cap.isOpened():
    status, frame = cap.read()

    if not status:
        break
    
    print("[INFO] Processing frame ", frame_count)
    (bbox, label, conf) = cv.detect_common_objects(frame)
    out = draw_bbox(frame, bbox, label, conf)
    print(bbox, label, conf)

    writer.write(out)
    frame_count += 1
# Out:
# [INFO] Processing frame  0
# ...
#   0% |                                                                        |
# ...
# [[8, 206, 480, 850], [346, 735, 478, 846]] ['person', 'remote'] [0.9704773426055908, 0.7886342406272888]
# [INFO] Processing frame  1
# [[1, 170, 485, 853], [328, 732, 476, 848]] ['person', 'cell phone'] [0.9736849069595337, 0.6402212977409363]
# [INFO] Processing frame  2
# [[-1, 176, 483, 851], [308, 731, 475, 846]] ['person', 'remote'] [0.9747313261032104, 0.7513274550437927]
# [INFO] Processing frame  3
# [[2, 173, 479, 850], [293, 728, 453, 848]] ['person', 'cell phone'] [0.9789923429489136, 0.8903063535690308]
# [INFO] Processing frame  4
# [[4, 164, 478, 857], [276, 726, 438, 848]] ['person', 'cell phone'] [0.9777922630310059, 0.9494020938873291]
# [INFO] Processing frame  5
# [[3, 160, 480, 858], [260, 725, 427, 848]] ['person', 'cell phone'] [0.979805588722229, 0.9667146801948547]
# [INFO] Processing frame  6
# ...

# %%
cap.release()
writer.release()
